# %%
#Install all the Reqiuired Libraries and Packages 
import os
import glob
from tqdm.autonotebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc , logfbank
import librosa as lr
import os, glob, pickle
import librosa
from scipy import signal
import noisereduce as nr
from glob import glob
import librosa
get_ipython().magic('matplotlib inline')
#All the Required Packages and Libraies are installed.
import soundfile
from tensorflow.keras.layers import Conv2D,MaxPool2D, Flatten, LSTM
from keras.layers import Dropout,Dense,TimeDistributed
from keras.models import Sequential
from keras.utils import to_categorical 
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   after removing the cwd from sys.path.

# %%
#Loading the required RAVDESS DataSet with length of 1439 Audio Files 
os.listdir(path='C:/Users/hp/Desktop/SER/Speech_Emotion_Detection-master/speech-emotion-recognition-ravdess-data')
def getListOfFiles(dirName):
    listOfFile=os.listdir(dirName)
    allFiles=list()
    for entry in listOfFile:
        fullPath=os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles=allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

dirName = 'C:/Users/hp/Desktop/SER/Speech_Emotion_Detection-master/speech-emotion-recognition-ravdess-data'
listOfFiles = getListOfFiles(dirName)
len(listOfFiles)
# Out:
# 1439

# %%
#Use the Speech-Recognition API to get the Raw Text from Audio Files, Though Speech Recognition
#is less strong for large chunk of files , so used Error Handling , where when it is not be able to 
#produce the text of a particular Audio File it prints the statement 'error'.Just for understanding Audio
import speech_recognition as sr
r=sr.Recognizer()
for file in range(0 , len(listOfFiles) , 1):
    with sr.AudioFile(listOfFiles[file]) as source:
        audio = r.listen(source)
        try:
            text = r.recognize_google(audio)
            print(text)
        except:
            print('error')
# Out:
# is it talking by the door
# dog sitting by the door
# talk to Siri why the door
# error
# error
# error
# dog sitting by the door
# change your talking by the door
# kids talking by the door
# dogs sitting by the door
# sitting by the
# kids talking by the door
# talking by the door
# dog sitting by the door
# error
# talking by the door
# error
# sitting by the door
# error
# kids talking by the door
# khesa talking by the door
# error
# error
# kids talking by the door
# talking by the door
# dogs sitting by the door
# sitting by the door
# talking by the door
# is a talking by the door
# the door
# error
# the door
# Earth talking by the door
# frogs are sitting by the door
# dogs are sitting at the door
# talking by the door
# kids talking by the door
# dogs sitting by the door
# dogs sitting by the door
# f****** by the door
# is the talking to the door
# Rockstar ceiling by the door
# ceiling by the
# error
# khinch
# sitting by the door
# coronavirus
# kids talking by the door
# talking by the door
# tour tour
# exit the door
# kids talking
# kids talking by the door
# dogs sitting by the door
# error
# Ijjat
# talking by the door
# sitting by the door
# toxicity by the door
# kids talking by the door
# kids talking by the door
# dogs are sitting by the door
# talk just sitting by the door
# it's a talking by the door
# hits at hacking by the door
# dogs are sitting by the tower
# sitting by the door
# kids talking by the
# kids attacking Bible
# dogs are sitting by the door
# tags setting
# talking by the door
# error
# dogs are sitting by the door
# dogs are sitting by the door
# error
# error
# jobs in sitting by the driver
# Jhansi
# Ijjat Hawking by the tour
# talking by the door
# dogs sitting by the door
# target setting by the tour
# talking by the tour
# Ijjat hacking by the to
# talk with sitting by the tour
# talk was sitting by the tour
# talking by the door
# talking by the door
# dog sitting by the door
# dog sitting by the door
# talking by the door
# kids talking about the door
# dogs are standing by the door
# dogs sitting by the door
# talking by the door
# talking by the Joker
# tox was sitting by the Joker
# talk just sitting by the Shore
# error
# Talking Ben the dog
# talks of cinema
# top 15 budget
# talking by the door
# f****** by the door
# error
# top just sitting by the door
# kids f****** by the door
# kids talking by the door
# dogs staring by the door
# dogs staring by the door
# talking by the door
# talking by the door
# sitting by the door
# talk to setting by the door
# the door
# talking
# error
# error
# talking by the door
# talking
# sitting by the door
# charger sitting by the door
# talking Titan
# talking by the door
# error
# Siri
# talking by the door
# talking bicycle
# error
# charge sharing by the tour
# error
# by the door
# sitting by the Shore
# sitting by the door
# whore
# kids are talking
# talk to the door
# sitting by the door
# Satta King
# hit the talking by the door
# set setting
# search string by date
# Pitbull
# error
# error
# ek baat Bataun
# talking part 2
# talking
# accident
# error
# balto
# talking toe
# error
# error
# talking
# are talking by the door
# torturing fight over
# Ram Charan father
# error
# which is the tour
# error
# shortest path
# Jharkhand
# talking
# sharing button
# thought that setting barbacoa
# hot
# Chetan
# dogs are sitting pattern
# sitting by the door
# error
# error
# error
# ceiling fan
# error
# error
# error
# staring at the door
# talking by the door
# talking by the door
# dog racing by the door
# top 10 sitting by the door
# talking by the driver
# talking by the dohe
# dogs sitting by the door
# dogs at sitting batua
# that Hawking but it over
# talking by the tower
# Agra sitting by the tower
# dogs sitting at the door
# the talking by the river
# talking by the door
# Etawah
# chocolate selling by the Joker
# the talking by the door
# talking baddua
# stop the string that over
# error
# talking by the tower
# the talking by the door
# stop the sitting by the door
# top 10 sitting by the door
# error
# weather tour
# error
# error
# talking by the door
# error
# sitting by the door
# dog sitting by the door
# error
# error
# show the sitting by the drawer
# error
# talking by the door
# talking by the door
# stock was sitting by the door
# sitting by the door
# error
# error
# error
# error
# shit talking by the door
# talking but the door
# dog sitting by the door
# setting button
# talking by the door
# talking by the door
# top 10 sitting by the door
# stock that ceiling budget tour
# Utha Ke Mare Jor
# talking by the door
# sitting by the door
# sitting by the door
# at the door
# ki badi Jor
# error
# error
# kids are talking by the door
# kids are talking by the door
# dogs setting bar the door
# dogs are sitting by the door
# kids are talking by the door
# kids are talking
# dogs are sitting party door
# dogs are sitting by the door
# Kates 8 parking
# shades
# error
# dogs are sitting
# kids talking by the door
# talking by the door
# error
# dogs sitting by the door
# Kids Art
# Khet aur talking by the door
# error
# the door
# kids talking by the door
# kids are talking by the door
# talk it over
# dogs are sitting by the door
# error
# Khesari talking at the door
# roxid syrup
# transistor in motherboard
# are talking by the
# kids are talking by the door
# dogs are sitting by the door
# error
# kids talking by the door
# tricks of talking for the tour
# ostrich
# auto
# error
# kids talking
# error
# error
# talking or
# Kids Art
# talk it over
# Georgette saree madarchod
# Kids Art talking
# Khet Jaat Hawking
# error
# error
# kids are talking
# kids are talking
# sharing

# %%
#Now Cleaning Step is Performed where:
#DOWN SAMPLING OF AUDIO FILES IS DONE  AND PUT MASK OVER IT AND DIRECT INTO CLEAN FOLDER
#MASK IS TO REMOVE UNNECESSARY EMPTY VOIVES AROUND THE MAIN AUDIO VOICE 
def envelope(y , rate, threshold):
    mask=[]
    y=pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10) ,  min_periods=1 , center = True).mean()
    for mean in y_mean:
        if mean>threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

# %%
#Plotting the Basic Graphs for understanding of Audio Files :
for file in range(0 , len(listOfFiles) , 1):
    audio , sfreq = lr.load(listOfFiles[file])
    time = np.arange(0 , len(audio)) / sfreq
    
    fig ,ax = plt.subplots()
    ax.plot(time , audio)
    ax.set(xlabel = 'Time (s)' , ylabel = 'Sound Amplitude')
    plt.show()
    
#PLOT THE SEPCTOGRAM
for file in range(0 , len(listOfFiles) , 1):
     sample_rate , samples = wavfile.read(listOfFiles[file])
     frequencies , times, spectrogram = signal.spectrogram(samples, sample_rate) 
     plt.pcolormesh(times, frequencies, spectrogram)
     plt.imshow(spectrogram)
     plt.ylabel('Frequency [Hz]')
     plt.xlabel('Time [sec]')
     plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-aa566e6b3fc6> in <module>
#       1 #Plotting the Basic Graphs for understanding of Audio Files :
#       2 for file in range(0 , len(listOfFiles) , 1):
# ----> 3     audio , sfreq = lr.load(listOfFiles[file])
#       4     time = np.arange(0 , len(audio)) / sfreq
#       5
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     170
#     171     if sr is not None:
# --> 172         y = resample(y, sr_native, sr, res_type=res_type)
#     173
#     174     else:
#
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     582         y_hat = samplerate.resample(y.T, ratio, converter_type=res_type).T
#     583     else:
# --> 584         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     585
#     586     if fix:
#
# ~\anaconda3\lib\site-packages\resampy\core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
#Next Step is In-Depth Visualisation of Audio Fiels and its certain features to plot for.
#They are the Plotting Functions to be called later. 
def plot_signals(signals):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Time Series' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(signals.keys())[i])
            axes[x,y].plot(list(signals.values())[i])
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def plot_fft(fft):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Fourier Transform' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            data = list(fft.values())[i]
            Y,freq = data[0] , data[1]
            axes[x,y].set_title(list(fft.keys())[i])
            axes[x,y].plot(freq , Y)
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
    
def plot_fbank(fbank):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Filter Bank Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(fbank.keys())[i])
            axes[x,y].imshow(list(fbank.values())[i],cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1
            
def plot_mfccs(mfccs):
    fig , axes = plt.subplots(nrows=2, ncols=5,sharex =False , sharey=True, figsize=(20,5))
    fig.suptitle('Mel Frequency Capstrum  Coefficients' , size=16)
    i=0
    for x in range(2):
        for y in range(5):
            axes[x,y].set_title(list(mfccs.keys())[i])
            axes[x,y].imshow(list(mfccs.values())[i],
                             cmap='hot', interpolation = 'nearest')
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i +=1

def calc_fft(y,rate):
    n = len(y)
    freq = np.fft.rfftfreq(n , d= 1/rate)
    Y= abs(np.fft.rfft(y)/n)
    return(Y,freq)

# %%
# Here The Data Set is loaded and plots are Visualised by Calling the Plotting Functions . 
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
for file in range(0 , len(listOfFiles) , 1):
    rate, data = wav.read(listOfFiles[file])
    fft_out = fft(data)
    # %matplotlib inline
    plt.plot(data, np.abs(fft_out))
    plt.show()
    
signals={}
fft={}
fbank={}
mfccs={}
# load data
for file in range(0 , len(listOfFiles) , 1):
#     rate, data = wavfile.read(listOfFiles[file])
     signal,rate =librosa.load(listOfFiles[file] , sr=44100)
     mask = envelope(signal , rate , 0.0005)
     signals[file] = signal
     fft[file] = calc_fft(signal , rate)
    
     bank = logfbank(signal[:rate] , rate , nfilt = 26, nfft = 1103).T
     fbank[file] = bank
     mel = mfcc(signal[:rate] , rate , numcep =13 , nfilt = 26 , nfft=1103).T
     mfccs[file]=mel

plot_signals(signals)
plt.show()

plot_fft(fft)
plt.show()

plot_fbank(fbank)
plt.show()

plot_mfccs(mfccs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f199d0e15720> in <module>
#       8     fft_out = fft(data)
#       9     get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 10     plt.plot(data, np.abs(fft_out))
#      11     plt.show()
#      12
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#    2366 @_copy_docstring_and_deprecators(Figure.gca)
#    2367 def gca(**kwargs):
# -> 2368     return gcf().gca(**kwargs)
#    2369
#    2370
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in gca(self, **kwargs)
#    2063
#    2064         # no axes found, so create one which spans the figure
# -> 2065         return self.add_subplot(1, 1, 1, **kwargs)
#    2066
#    2067     def sca(self, a):
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1108         self.containers = []
#    1109
# -> 1110         self.grid(False)  # Disable grid on init to use rcParameter
#    1111         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1112                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2890             self.xaxis.grid(b, which=which, **kwargs)
#    2891         if axis in ['y', 'both']:
# -> 2892             self.yaxis.grid(b, which=which, **kwargs)
#    2893
#    2894     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1449             elif b is not None:
#    1450                 gridkw['gridOn'] = b
# -> 1451             self.set_tick_params(which='major', **gridkw)
#    1452         self.stale = True
#    1453
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     836             if which in ['major', 'both']:
#     837                 self._major_tick_kw.update(kwtrans)
# --> 838                 for tick in self.majorTicks:
#     839                     tick._apply_params(**kwtrans)
#     840             if which in ['minor', 'both']:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     617                 instance.majorTicks = []
#     618                 tick = instance._get_tick(major=True)
# --> 619                 instance.majorTicks.append(tick)
#     620                 return instance.majorTicks
#     621             else:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     616             if self._major:
#     617                 instance.majorTicks = []
# --> 618                 tick = instance._get_tick(major=True)
#     619                 instance.majorTicks.append(tick)
#     620                 return instance.majorTicks
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2304         else:
#    2305             tick_kw = self._minor_tick_kw
# -> 2306         return YTick(self.axes, 0, major=major, **tick_kw)
#    2307
#    2308     def set_label_position(self, position):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     488
#     489     def __init__(self, *args, **kwargs):
# --> 490         super().__init__(*args, **kwargs)
#     491         # x in axes coords, y in data coords
#     492         self.tick1line.set(
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     164         )
#     165         self.gridline.get_path()._interpolation_steps = \
# --> 166             GRIDLINE_INTERPOLATION_STEPS
#     167         self.label1 = mtext.Text(
#     168             np.nan, np.nan,
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1009         """
#    1010         if self._invalidy or self._invalidx:
# -> 1011             self.recache()
#    1012         return self._path
#    1013
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     685         xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy.T)
#     686         self._path = Path(np.asarray(xy).T,
# --> 687                           _interpolation_steps=interpolation_steps)
#     688         self._transformed_path = None
#     689         self._invalidx = False
#
# ~\anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     130         """
#     131         vertices = _to_unmasked_float_array(vertices)
# --> 132         cbook._check_shape((None, 2), vertices=vertices)
#     133
#     134         if codes is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_shape(_shape, **kwargs)
#    2291         if len(target_shape) != len(data_shape) or any(
#    2292                 t not in [s, None]
# -> 2293                 for t, s in zip(target_shape, data_shape)
#    2294         ):
#    2295             dim_labels = iter(itertools.chain(
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in <genexpr>(.0)
#    2290
#    2291         if len(target_shape) != len(data_shape) or any(
# -> 2292                 t not in [s, None]
#    2293                 for t, s in zip(target_shape, data_shape)
#    2294         ):
#
# KeyboardInterrupt:

# %%
#Now Cleaning Step is Performed where:
#DOWN SAMPLING OF AUDIO FILES IS DONE  AND PUT MASK OVER IT AND DIRECT INTO CLEAN FOLDER
#MASK IS TO REMOVE UNNECESSARY EMPTY VOIVES AROUND THE MAIN AUDIO VOICE 
def envelope(y , rate, threshold):
    mask=[]
    y=pd.Series(y).apply(np.abs)
    y_mean = y.rolling(window=int(rate/10) ,  min_periods=1 , center = True).mean()
    for mean in y_mean:
        if mean>threshold:
            mask.append(True)
        else:
            mask.append(False)
    return mask

# %%
#pip install ipywidgets

# %%
#The clean Audio Files are redirected to Clean Audio Folder Directory 
import glob,pickle
for file in tqdm(glob.glob(r'C:/Users/hp/Desktop/Speech_Emotion_Detection-master/speech-emotion-recognition-ravdess-data//**//*.wav')):
    file_name = os.path.basename(file)
    signal , rate = librosa.load(file, sr=16000)
    mask = envelope(signal,rate, 0.0005)
    wavfile.write(filename= r'C:/Users/hp/Desktop/Speech_Emotion_Detection-master/clean_speech//'+str(file_name), rate=rate,data=signal[mask])
# Out:
#   0%|          | 0/1439 [00:00<?, ?it/s]

# %%
#Feature Extraction of Audio Files Function 
#Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
        result=np.hstack((result, mel))
    return result

# %%
#Emotions in the RAVDESS dataset to be classified Audio Files based on . 
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
#These are the emotions User wants to observe more :
observed_emotions=['calm', 'happy', 'fearful', 'disgust','sad','angry','surprised','neutral']

# %%
#Load the data and extract features for each sound file
from glob import glob
import os
import glob
def load_data(test_size=0.33):
    x,y=[],[]
    answer = 0
    for file in glob.glob(r'C:/Users/hp/Desktop/SER/Speech_Emotion_Detection-master/clean_speech\\*.wav'):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            answer += 1
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append([emotion,file_name])
    return train_test_split(np.array(x), y, test_size=test_size, random_state=10)

# %%
#Split the dataset
import librosa
import numpy as np
x_train,x_test,y_trai,y_tes=load_data(test_size=0.25)
print(np.shape(x_train),np.shape(x_test), np.shape(y_trai),np.shape(y_tes))
y_test_map = np.array(y_tes).T
y_test = y_test_map[0]
test_filename = y_test_map[1]
y_train_map = np.array(y_trai).T
y_train = y_train_map[0]
train_filename = y_train_map[1]
print(np.shape(y_train),np.shape(y_test))
print(*test_filename,sep="\n")
# Out:
# (1079, 180) (360, 180) (1079, 2) (360, 2)
# (1079,) (360,)
# 03-01-06-02-01-02-23.wav
# 03-01-07-02-01-01-13.wav
# 03-01-07-02-02-02-22.wav
# 03-01-04-01-01-01-05.wav
# 03-01-02-01-01-02-07.wav
# 03-01-03-01-01-02-16.wav
# 03-01-08-02-01-02-13.wav
# 03-01-07-01-02-01-06.wav
# 03-01-01-01-01-02-13.wav
# 03-01-06-02-02-01-01.wav
# 03-01-07-02-01-01-07.wav
# 03-01-04-02-02-02-19.wav
# 03-01-04-01-02-02-15.wav
# 03-01-08-02-02-01-06.wav
# 03-01-02-01-02-02-05.wav
# 03-01-08-01-02-01-23.wav
# 03-01-07-02-01-01-14.wav
# 03-01-06-02-02-01-16.wav
# 03-01-07-02-02-01-10.wav
# 03-01-02-02-01-02-14.wav
# 03-01-06-02-01-02-06.wav
# 03-01-08-02-02-01-11.wav
# 03-01-03-02-02-01-15.wav
# 03-01-02-01-01-01-08.wav
# 03-01-03-01-02-02-17.wav
# 03-01-04-02-02-02-08.wav
# 03-01-08-02-01-02-04.wav
# 03-01-01-01-02-02-17.wav
# 03-01-07-01-02-02-22.wav
# 03-01-01-01-01-01-09.wav
# 03-01-08-01-02-02-23.wav
# 03-01-05-01-02-01-17.wav
# 03-01-08-01-02-02-05.wav
# 03-01-08-01-01-02-15.wav
# 03-01-06-01-01-01-04.wav
# 03-01-08-02-01-02-08.wav
# 03-01-02-02-01-01-01.wav
# 03-01-05-02-02-02-16.wav
# 03-01-02-01-02-02-24.wav
# 03-01-08-02-02-01-14.wav
# 03-01-05-01-01-01-08.wav
#         4.43051606e-02,  2.84470022e-01,  6.10593617e-01,  2.81184614e-01,
#         1.41073596e+00,  5.05678117e-01,  1.21116554e-02,  1.76814515e-02,
#         2.30126962e-01,  3.52987200e-01,  1.25698254e-01,  6.81229085e-02,
#         1.33259473e-02,  2.51946691e-02,  2.98834592e-02,  7.63198808e-02,
#         9.61483419e-02,  2.98961774e-02,  1.61382835e-02,  1.25520946e-02,
#         3.90391126e-02,  1.05235018e-01,  3.05604879e-02,  6.67177467e-03,
#         7.96460267e-03,  2.98050493e-02,  4.03056890e-02,  1.32704182e-02,
#         5.24993008e-03,  6.37818361e-03,  9.03325155e-03,  4.09527123e-02,
#         1.95112899e-02,  6.34462014e-03,  1.46840001e-02,  1.87992752e-02,
#         1.62696820e-02,  8.14478565e-03,  1.63889863e-02,  4.91260290e-02,
#         1.64780170e-02,  6.32563466e-03,  1.63215883e-02,  6.37961924e-03,
#         4.27911058e-03,  6.89811865e-03,  3.69079853e-03,  6.29354082e-03,
#         6.40143454e-03,  6.63316390e-03,  4.83998330e-03,  6.32263348e-03,
#         3.71419732e-03,  9.15909559e-03,  8.08150787e-03,  3.96398595e-03,
#         2.31348746e-03,  7.99824076e-04,  6.38824131e-04,  7.43282493e-04,
#         8.78771534e-04,  8.91199626e-04,  1.03709113e-03,  8.79341445e-04,
#         1.01115054e-03,  9.44866857e-04,  1.60511618e-03,  1.14399416e-03,
#         8.29505094e-04,  1.10382284e-03,  1.60882284e-03,  1.60945859e-03,
#         1.46976998e-03,  1.09890581e-03,  8.59684311e-04,  1.06251112e-03,
#         8.80195003e-04,  8.68287403e-04,  6.84795843e-04,  5.14234707e-04,
#         5.28637494e-04,  3.46983172e-04,  3.00404121e-04,  2.76265462e-04,
#         4.07090294e-04,  6.34488300e-04,  4.23977617e-04,  1.83409182e-04]))
# Features extracted: 180

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
#Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
#SAVING THE MODEL
import pickle
# Save the Modle to file in the current working directory
#For any new testing data other than the data in dataset

Pkl_Filename = "Emotion_Voice_Detection_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %%
# Load the Model back from file
with open(Pkl_Filename, 'rb') as file:  
    Emotion_Voice_Detection_Model = pickle.load(file)

Emotion_Voice_Detection_Model
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
#predicting :
y_pred=Emotion_Voice_Detection_Model.predict(x_test)
y_pred
# Out:
# array(['happy', 'sad', 'disgust', 'neutral', 'calm', 'fearful', 'sad',
#        'calm', 'calm', 'fearful', 'angry', 'sad', 'sad', 'happy', 'calm',
#        'surprised', 'disgust', 'fearful', 'surprised', 'sad', 'happy',
#        'surprised', 'disgust', 'sad', 'fearful', 'fearful', 'angry',
#        'neutral', 'disgust', 'fearful', 'surprised', 'sad', 'surprised',
#        'neutral', 'sad', 'surprised', 'calm', 'angry', 'calm',
#        'surprised', 'happy', 'happy', 'disgust', 'calm', 'surprised',
#        'calm', 'angry', 'fearful', 'disgust', 'surprised', 'disgust',
#        'angry', 'happy', 'sad', 'angry', 'sad', 'calm', 'neutral', 'calm',
#        'sad', 'surprised', 'fearful', 'angry', 'calm', 'surprised',
#        'disgust', 'calm', 'fearful', 'disgust', 'calm', 'surprised',
#        'fearful', 'sad', 'calm', 'calm', 'fearful', 'neutral',
#        'surprised', 'surprised', 'fearful', 'calm', 'surprised', 'calm',
#        'calm', 'angry', 'fearful', 'surprised', 'calm', 'happy', 'angry',
#        'fearful', 'happy', 'fearful', 'calm', 'calm', 'neutral',
#        'surprised', 'happy', 'calm', 'disgust', 'angry', 'fearful',
#        'fearful', 'sad', 'angry', 'disgust', 'sad', 'sad', 'sad', 'happy',
#        'surprised', 'disgust', 'disgust', 'fearful', 'sad', 'calm', 'sad',
#        'disgust', 'fearful', 'fearful', 'calm', 'sad', 'fearful', 'sad',
#        'neutral', 'angry', 'neutral', 'calm', 'happy', 'surprised',
#        'surprised', 'surprised', 'angry', 'fearful', 'fearful', 'sad',
#        'sad', 'fearful', 'sad', 'fearful', 'happy', 'calm', 'angry',
#        'sad', 'angry', 'neutral', 'surprised', 'happy', 'calm', 'happy',
#        'calm', 'calm', 'calm', 'disgust', 'angry', 'neutral', 'surprised',
#        'happy', 'sad', 'fearful', 'calm', 'neutral', 'disgust', 'calm',
#        'angry', 'surprised', 'angry', 'angry', 'happy', 'happy', 'happy',
#        'fearful', 'angry', 'sad', 'neutral', 'sad', 'fearful', 'happy',
#        'fearful', 'angry', 'sad', 'angry', 'disgust', 'calm', 'surprised',
#        'angry', 'calm', 'sad', 'angry', 'calm', 'happy', 'calm',
#        'neutral', 'happy', 'sad', 'sad', 'fearful', 'disgust', 'sad',
#        'happy', 'surprised', 'calm', 'neutral', 'disgust', 'surprised',
#        'surprised', 'fearful', 'happy', 'disgust', 'sad', 'happy',
#        'disgust', 'surprised', 'disgust', 'calm', 'fearful', 'sad',
#        'surprised', 'sad', 'happy', 'fearful', 'angry', 'sad', 'sad',
#        'sad', 'neutral', 'fearful', 'happy', 'sad', 'sad', 'disgust',
#        'neutral', 'fearful', 'calm', 'calm', 'angry', 'angry', 'neutral',
#        'surprised', 'angry', 'calm', 'disgust', 'surprised', 'disgust',
#        'angry', 'calm', 'disgust', 'surprised', 'calm', 'happy',
#        'disgust', 'fearful', 'angry', 'neutral', 'surprised', 'disgust',
#        'happy', 'sad', 'happy', 'happy', 'neutral', 'neutral', 'calm',
#        'surprised', 'angry', 'calm', 'surprised', 'sad', 'angry', 'angry',
#        'calm', 'disgust', 'disgust', 'disgust', 'surprised', 'surprised',
#        'sad', 'sad', 'surprised', 'happy', 'calm', 'fearful', 'surprised',
#        'neutral', 'angry', 'surprised', 'sad', 'fearful', 'fearful',
#        'happy', 'fearful', 'surprised', 'calm', 'calm', 'disgust',
#        'angry', 'happy', 'neutral', 'angry', 'angry', 'neutral',
#        'disgust', 'disgust', 'disgust', 'fearful', 'angry', 'sad',
#        'fearful', 'calm', 'sad', 'neutral', 'happy', 'happy', 'angry',
#        'fearful', 'disgust', 'fearful', 'sad', 'happy', 'angry',
#        'neutral', 'fearful', 'neutral', 'disgust', 'happy', 'calm', 'sad',
#        'angry', 'surprised', 'surprised', 'fearful', 'happy', 'disgust',
#        'surprised', 'disgust', 'surprised', 'angry', 'angry', 'surprised',
#        'calm', 'neutral', 'angry', 'sad', 'disgust', 'calm', 'fearful',
#        'disgust', 'sad', 'angry', 'angry', 'surprised', 'disgust', 'calm',
#        'happy', 'happy', 'disgust', 'angry', 'surprised', 'fearful',
#        'calm'], dtype='<U9')

# %%
#Store the Prediction probabilities into CSV file 
import numpy as np
import pandas as pd
y_pred1 = pd.DataFrame(y_pred, columns=['predictions'])
y_pred1['file_names'] = test_filename
print(y_pred1)
y_pred1.to_csv('predictionfinal.csv')
# Out:
#     predictions                file_names
# 0         happy  03-01-06-02-01-02-23.wav
# 1           sad  03-01-07-02-01-01-13.wav
# 2       disgust  03-01-07-02-02-02-22.wav
# 3       neutral  03-01-04-01-01-01-05.wav
# 4          calm  03-01-02-01-01-02-07.wav
# ..          ...                       ...
# 355     disgust  03-01-02-01-02-02-06.wav
# 356       angry  03-01-05-02-02-02-19.wav
# 357   surprised  03-01-01-01-01-01-03.wav
# 358     fearful  03-01-06-02-02-02-22.wav
# 359        calm  03-01-02-02-01-02-15.wav
#
# [360 rows x 2 columns]

# %%
new_feature= extract_feature("C:/Users/hp/Desktop/SER/Speech_Emotion_Detection-master/03-01-02-01-01-02-06.wav", mfcc=True, chroma=True, mel=True)
new_feature.shape

Emotion_Voice_Detection_Model.predict([new_feature])
# Out:
# array(['calm'], dtype='<U9')

# %%
#RECORDED USING MICROPHONE:
import pyaudio
import wave

CHUNK = 1024 
FORMAT = pyaudio.paInt16 #paInt8
CHANNELS = 2 
RATE = 44100 #sample rate
RECORD_SECONDS = 4
WAVE_OUTPUT_FILENAME = "output10.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK) #buffer

print("* recording")
frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data) # 2 bytes(16 bits) per channel

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# * recording
# * done recording

# %%
#The file 'output10.wav' in the next cell is the file that was recorded live using the code :
data, sampling_rate = librosa.load('C:/Users/hp/Downloads/2021-03-09T03_36_47.955Z.wav')
# %matplotlib inline
import os
import pandas as pd
import librosa.display
import glob 

plt.figure(figsize=(15, 5))
librosa.display.waveplot(data, sr=sampling_rate)

# %%
## Appying extract_feature function on random file and then loading model to predict the result 
file = 'C:/Users/hp/Desktop/fear112.wav'

new_feature= extract_feature(file, mfcc=True, chroma=True, mel=True)


Emotion_Voice_Detection_Model.predict([new_feature])
# Out:
# array(['fearful'], dtype='<U9')
